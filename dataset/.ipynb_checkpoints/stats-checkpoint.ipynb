# %%
import pandas as pd
import os

df = pd.read_csv(r"C:\Users\oozgen\Desktop\phd\dataset\ASOptimizer_main.csv")

# Display the first 5 rows to ensure it loaded correctly
display(df.head())
# Out:
#    ISIS Target_gene Cell_line Density(cells/well) Transfection  \
# 0     0       HIF1A      Hela                 NaN          NaN
# 1     2       HIF1A      Hela                 NaN          NaN
# 2     5       HIF1A      Hela                 NaN          NaN
# 3     6       HIF1A      Hela                 NaN          NaN
# 4     7       HIF1A      Hela                 NaN          NaN
#
#    ASO_volume(nM)  Treatment_Period(hours) Primer_probe_set          Sequence  \
# 0           100.0                       24              NaN  TGGCAAGCATCCTGTA
# 1           100.0                       24              NaN  TGGCAAGCATCCTGTA
# 2           100.0                       24              NaN  TGGCAAGCATCCTGTA
# 3           100.0                       24              NaN  TGGCAAGCATCCTGTA
# 4           100.0                       24              NaN  TGGCAAGCATCCTGTA
#
#   Modification      Location  Chemical_Pattern           Linkage  \
# 0    LNA/deoxy     0?15/else  LddddddddddddddL  phosphorothioate
# 1    LNA/deoxy   0?2?15/else  LdLddddddddddddL  phosphorothioate
# 2    LNA/deoxy  0?11?15/else  LddddddddddLdddL  phosphorothioate
# 3    LNA/deoxy  0?12?15/else  LdddddddddddLddL  phosphorothioate
# 4    LNA/deoxy  0?13?15/else  LddddddddddddLdL  phosphorothioate
#
#   Linkage_Location                                             Smiles  \
# 0             else  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...
# 1             else  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...
# 2             else  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...
# 3             else  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...
# 4             else  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@]34CO[C@...
#
#    Inhibition(%)  seq_length
# 0           40.0          16
# 1           62.9          16
# 2           46.1          16
# 3           57.5          16
# 4           46.0          16

# %%
# Check total rows, columns, data types, and memory usage
print("--- DataFrame Info ---")
df.info()

print("\n--- Missing Values per Column ---")
# This tells you if any columns have blank/NaN values
print(df.isnull().sum())
# Out:
# --- DataFrame Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 31752 entries, 0 to 31751
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ISIS                     31752 non-null  int64
#  1   Target_gene              31752 non-null  str
#  2   Cell_line                31752 non-null  str
#  3   Density(cells/well)      27479 non-null  str
#  4   Transfection             27323 non-null  str
#  5   ASO_volume(nM)           31752 non-null  float64
#  6   Treatment_Period(hours)  31752 non-null  int64
#  7   Primer_probe_set         27930 non-null  str
#  8   Sequence                 31752 non-null  str
#  9   Modification             31752 non-null  str
#  10  Location                 31752 non-null  str
#  11  Chemical_Pattern         31752 non-null  str
#  12  Linkage                  31752 non-null  str
#  13  Linkage_Location         31752 non-null  str
#  14  Smiles                   31752 non-null  str
#  15  Inhibition(%)            31752 non-null  float64
#  16  seq_length               31752 non-null  int64
# dtypes: float64(2), int64(3), str(12)
# memory usage: 39.5 MB
#
# --- Missing Values per Column ---
# ISIS                          0
# Target_gene                   0
# Cell_line                     0
# Density(cells/well)        4273
# Transfection               4429
# ASO_volume(nM)                0
# Treatment_Period(hours)       0
# Primer_probe_set           3822
# Sequence                      0
# Modification                  0
# Location                      0
# Chemical_Pattern              0
# Linkage                       0
# Linkage_Location              0
# Smiles                        0
# Inhibition(%)                 0
# seq_length                    0
# dtype: int64

# %%
# 1. Statistics for NUMERIC columns 
# (e.g., Density, ASO_volume, Treatment_Period, Inhibition, seq_length)
print("--- Numeric Statistics ---")
display(df.describe())

# 2. Statistics for CATEGORICAL/TEXT columns 
# (e.g., Target_gene, Cell_line, Sequence, Smiles)
print("--- Categorical Statistics ---")
display(df.describe(include=['object', "str"]))
# Out:
# --- Numeric Statistics ---
#                ISIS  ASO_volume(nM)  Treatment_Period(hours)  Inhibition(%)  \
# count  3.175200e+04     31752.00000             31752.000000   31752.000000
# mean   7.917338e+06      2937.38537                27.483245      44.016472
# std    1.880915e+07      4132.40071                12.170108      29.693042
# min    0.000000e+00         0.67000                16.000000    -786.000000
# 25%    6.959128e+05       222.00000                24.000000      21.000000
# 50%    9.693795e+05      1000.00000                24.000000      45.000000
# 75%    1.246182e+06      4000.00000                24.000000      66.000000
# max    8.028016e+07     25000.00000               168.000000     100.000000
#
#          seq_length
# count  31752.000000
# mean      16.750000
# std        1.378275
# min       10.000000
# 25%       16.000000
# 50%       16.000000
# 75%       17.000000
# max       25.000000
# --- Categorical Statistics ---
#        Target_gene Cell_line Density(cells/well)     Transfection  \
# count        31752     31752               27479            27323
# unique          20        23                  11                5
# top           IRF4    HepaRG               20000  electroporation
# freq          5999      6450               10253            12414
#
#        Primer_probe_set           Sequence                 Modification  \
# count             27930              31752                        31752
# unique               22              15438                           12
# top            RTS43553  CAGCTTGGCGATGATCT  cEt/5-methylcytosines/deoxy
# freq               5455                191                        13156
#
#                      Location  Chemical_Pattern           Linkage  \
# count                   31752             31752             31752
# unique                   1561              1564                 4
# top     0?1?2?13?14?15/C/else  CCCddddddddddCCC  phosphorothioate
# freq                    11999             11981             29243
#
#        Linkage_Location                                             Smiles
# count             31752                                              31752
# unique               47                                              22755
# top                else  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...
# freq              29243                                                 26

# %%
# See the COUNT of unique values for every single column
print("--- Number of Unique Values per Column ---")
display(df.nunique())

# --- Deep Dive into Specific Columns ---

# View the actual unique names of the cell lines used
print("\nUnique Cell Lines:")
print(df['Cell_line'].unique())

# View the top 10 most frequently targeted genes
print("\nTop 10 Target Genes by frequency:")
print(df['Target_gene'].value_counts().head(10))

# View the different types of modifications applied
print("\nUnique Modifications:")
print(df['Modification'].value_counts())
# Out:
# --- Number of Unique Values per Column ---
# ISIS                       22733
# Target_gene                   20
# Cell_line                     23
# Density(cells/well)           11
# Transfection                   5
# ASO_volume(nM)                60
# Treatment_Period(hours)        7
# Primer_probe_set              22
# Sequence                   15438
# Modification                  12
# Location                    1561
# Chemical_Pattern            1564
# Linkage                        4
# Linkage_Location              47
# Smiles                     22755
# Inhibition(%)               1134
# seq_length                    12
# dtype: int64
# Unique Cell Lines:
# <ArrowStringArray>
# [                       'Hela',                  'KARPAS-229',
#                        'HepG2',                        'A431',
#                       'HepaRG',                   'SK-MEL-28',
#                        'MM.1R',                        'H929',
#                        'KMS11',                    'NCI-H460',
#                      'SH-SY5Y',                   'Human IPS',
#                      'SNU-449',              'LLC-MK2 monkey',
#             'PAC neurons asyn',               'SK cells asyn',
#                'Angptl2/Actin',                 'Oscillation',
#                      'Tubulin',         'Human Neuronal Cell',
#  'Mouse Primary Neuronal Cell',                        'U251',
#                      'CC-2580']
# Length: 23, dtype: str
#
# Top 10 Target Genes by frequency:
# Target_gene
# IRF4        5999
# HSD17B13    5455
# MALAT1      2606
# SOD-1       2181
# APOL1       2021
# DGAT2       1894
# SNHG14      1847
# SNCA        1632
# HBV         1599
# Yap1        1079
# Name: count, dtype: int64
#
# Unique Modifications:
# Modification
# cEt/5-methylcytosines/deoxy                       13156
# MOE/cEt/5-methylcytosines/deoxy                    7790
# MOE/5-methylcytosines/deoxy                        4723
# LNA/deoxy                                          4400
# cEt/o-methylribose/5-methylcytosines/deoxy          628
# MOE/(S)-cEt/5-methylcytosines/deoxy                 471
# (S)-cEt/5-methylcytosines/MOE/deoxy                 326
# (S)-cEt/5-methylcytosines/deoxy                     236
# MOE/cEt/o-methylribose/5-methylcytosines/deoxy        6
# LNA/OMe/deoxy                                         6
# 5-methylcytosines/deoxy                               5
# LNA/Amino/deoxy                                       5
# Name: count, dtype: int64

# %%
# Average inhibition percentage per Target Gene
avg_inhibition_by_gene = df.groupby('Target_gene')['Inhibition(%)'].mean().sort_values(ascending=False)

print("--- Average Inhibition (%) by Target Gene ---")
display(avg_inhibition_by_gene.head(10)) # Shows the top 10 most inhibited genes on average
# Out:
# --- Average Inhibition (%) by Target Gene ---
# Target_gene
# Tau         77.532242
# SNCA_LNA    74.436815
# HTRA1       73.265217
# APOL1       68.789708
# DGAT2       61.625132
# PKK         57.247236
# Yap1        54.195551
# HBV         52.093809
# SNCA        50.715074
# HIF1A       45.635156
# Name: Inhibition(%), dtype: float64

# %%
# 1. Count how many negative values you actually have
negative_count = len(df[df['Inhibition(%)'] < 0])
total_rows = len(df)
print(f"There are {negative_count} rows with negative inhibition out of {total_rows}.")

# 2. Look at the statistics of ONLY the negative values
print("\n--- Stats for Negative Inhibition Values ---")
display(df[df['Inhibition(%)'] < 0]['Inhibition(%)'].describe())

# 3. View the top 30 most extremely negative rows to see if a specific gene or ASO is responsible
extreme_negatives = df.sort_values(by='Inhibition(%)', ascending=True).head(30)
display(extreme_negatives[['Target_gene', 'Sequence', 'Inhibition(%)']])
# Out:
# There are 1282 rows with negative inhibition out of 31752.
#
# --- Stats for Negative Inhibition Values ---
# count    1282.000000
# mean      -13.717707
# std        27.364920
# min      -786.000000
# 25%       -17.000000
# 50%        -9.000000
# 75%        -4.000000
# max        -0.500000
# Name: Inhibition(%), dtype: float64
#       Target_gene             Sequence  Inhibition(%)
# 16593        IRF4     CCTTAAGCTATTTGGT         -786.0
# 18900      MALAT1     TCACCGGAATTCGATC         -263.0
# 18908      MALAT1     ACAACTCGCATCACCG         -212.0
# 12894        IRF4     GACTTAACCCACATCA         -166.0
# 20577      MALAT1     GCTGAAATCTATTCAA         -159.0
# 18819      MALAT1     ACAAAACCCCCGGAAC         -153.0
# 16613        IRF4     ACACAAGTCTTAGGTG         -153.0
# 16702        IRF4     TTTAAGAGGCGACTGC         -100.0
# 31637        MYH7    CAGCTTGGCGATGATCT          -75.0
# 12098        IRF4     ACAGAGGTGGGAGTAC          -74.0
# 31335        MYH7    CAGCTTGGCGATGATCT          -70.0
# 21981        Yap1     CTCTTATATGGTTTTG          -68.0
# 11841        IRF4     CACCATTCAGACAGAT          -67.0
# 31713        MYH7  CTTGGCAATGATCTCATCC          -62.0
# 11977        IRF4     AGGCAGTTGTGCCGTC          -62.0
# 12092        IRF4     CAGAGACGCGGTGAGA          -61.0
# 31440        MYH7   TCAGCTTGGCGATGATCT          -60.0
# 31381        MYH7    CAGCTTGGCGATGATCT          -60.0
# 29348      SNHG14   ACCAGCTACAGGAACCTC          -60.0
# 31598        MYH7  CTTGGCAATGATCTCATCC          -54.0
# 29476      SNHG14    TACCTACATCTCATACT          -53.0
# 31414        MYH7    CAGCTTGGCGATGATCT          -52.0
# 31415        MYH7    CAGCTTGGCGATGATCT          -51.0
# 11904        IRF4     CAGCATAGCATTATCT          -51.0
# 18670      MALAT1     TGATCTGCGGCCCCCC          -50.0
# 31400        MYH7    CAGCTTGGCGATGATCT          -50.0
# 18598      MALAT1     TTTAAAGTAGACCAAC          -49.0
# 29553      SNHG14     TCATCCCTCCAAGAAA          -48.0
# 31409        MYH7    CAGCTTGGCGATGATCT          -47.0
# 29550      SNHG14     TCATCCCTCCAAGAAA          -46.0
